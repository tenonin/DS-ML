# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.drop(columns=['id'],inplace=True)

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   4.133842e+07      3.370842      2.114757   2079.899736  1.510697e+04
# std    2.584552e+08      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    6.885000e+09     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
df.floors.value_counts().to_frame()
# Out:
#      floors
# 1.0   10680
# 2.0    8241
# 1.5    1910
# 3.0     613
# 2.5     161
# 3.5       8

# %%
import seaborn as sns

# %%
sns.boxplot(data=df,x='waterfront',y='price')
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
sns.regplot(data=df,x='sqft_above',y='price')
# Out:
# <AxesSubplot:xlabel='sqft_above', ylabel='price'>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X = df.sqft_living
y = df.price

X=X.values.reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(
                      X, y, test_size=0.33, random_state=42)

lm = LinearRegression().fit(X_train,y_train)
lm.score(X_train,y_train)
# Out:
# 0.11352345122259044

# %%
# X = df.loc[:,[df.sqft_living,df.grade,df.sqft_above,df.sqft_living15,df.bathrooms,df.view,df.sqft_basement,df.bedrooms,df.lat,df.bedrooms,df.waterfront,df.floors]]
X = df[['sqft_living','grade','sqft_above','sqft_living15','bathrooms','view','sqft_basement','bedrooms','lat','waterfront','floors']]
y = df[['price']]


X_train, X_test, y_train, y_test = train_test_split(
                      X, y, test_size=0.33, random_state=42)

lm = LinearRegression().fit(X_train,y_train)
lm.score(X_train,y_train)
# Out:
# 0.14908915109875032

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler

pipeline = Pipeline([('scaler', StandardScaler()), ('PR', PolynomialFeatures()),('LR',LinearRegression())])
parameters = {
    'PR__degree':[1,2,3,4]
}

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(pipeline, param_grid=parameters)
grid.fit(X_train,y_train)
grid.best_score_
# Out:
# 0.14149377545601033

# %%
from sklearn.linear_model import Ridge
clf = Ridge(alpha=0.1)
clf.fit(X_train,y_train)
clf.score(X_train,y_train)
# Out:
# 0.14908914384151672

# %%
pr = PolynomialFeatures(2)
prTrain = pr.fit(X_train,y_train)
prTest = pr.fit(X_test,y_test)

# %%
clf = Ridge(alpha=0.1)
clf.fit(X_train,y_train)
clf.score(X_test,y_test)
# Out:
# 0.08848475625830754
